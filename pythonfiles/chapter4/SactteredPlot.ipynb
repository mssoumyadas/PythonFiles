# %%
#read the data from CSV file and create a scattered plot.

import matplotlib.pyplot as plt
import numpy as np  
import pandas as pd
df = pd.read_csv('C:\\Users\\mssou\\pythonfiles\\TextFiles\\insurance.csv')
bmi = df['bmi'].to_numpy() # converting specific columns to numpy
charges= df['charges'].to_numpy()
gender= [female,male]
plt.scatter(bmi,charges)
plt.show()

# %%
import seaborn as sns
df = pd.read_csv(r'C:\Users\mssou\pythonfiles\TextFiles\insurance.csv')

# Use Seaborn's stripplot to handle categorical data (gender) automatically
plt.figure(figsize=(10, 6))
sns.stripplot(x='sex', y='charges', data=df, jitter=True, alpha=0.5)

plt.title('Insurance Charges by Gender')
plt.show()
