# %%
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
regular_day_range = pd.date_range(start="2026-02-27", periods=5, freq='D')
business_day_range = pd.date_range(start="2026-02-27", periods=5, freq='B')

# %%
regular_day_range
# Out:
# DatetimeIndex(['2026-02-27', '2026-02-28', '2026-03-01', '2026-03-02',
#                '2026-03-03'],
#               dtype='datetime64[ns]', freq='D')

# %%
business_day_range
# Out:
# DatetimeIndex(['2026-02-27', '2026-03-02', '2026-03-03', '2026-03-04',
#                '2026-03-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
NFLX=pd.read_csv("C:\\Users\\mssou\\pythonfiles\\TextFiles\\NFLX1.csv",index_col="Date", parse_dates=True)
# %matplotlib inline
NFLX['Close'].plot()
plt.show()

# %%
NFLX['Close'].describe()
# Out:
# count    1009.000000
# mean      419.000733
# std       108.289999
# min       233.880005
# 25%       331.619995
# 50%       378.670013
# 75%       509.079987
# max       691.690002
# Name: Close, dtype: float64

# %%
NFLX.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07
