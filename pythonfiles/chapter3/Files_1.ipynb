# %%
#file different way to set path
fobj1=open(r'C:\Users\mssou\pythonfiles\TextFiles\Welcome.txt','r')
print(id(fobj1))
# Out:
# 3012533381696

# %%
fobj2=open('C:\\Users\\mssou\\pythonfiles\\TextFiles\\Welcome.txt','r')
print(id(fobj2))
# Out:
# 3012533383264

# %%
fobj3=open('C:/Users/mssou/pythonfiles/TextFiles/Welcome.txt','r')
print(id(fobj3))
# Out:
# 3012533385280

# %%
fobj3=open('C:/Users/mssou/pythonfiles/TextFiles/Welcome.txt','r')
print(id(fobj3))
fobj3.seek(0)
print(fobj3.read()) #read first 7 positions
print(fobj3.name)
print(fobj3.tell()) #tell is on 7th position
print(fobj3.mode)
print(fobj3.fileno())
print(fobj3.writable())
print(fobj3.seekable())
print(fobj3.close())
print(fobj3.closed)
# Out:
# 3012533385952
# Welcome to Python.
# 1 Mimo
# 2 Minsi
# 3 Insy
# 4 simon
# 5 cuteness
# 6 mimoness
# 7 sugar
# 8 salt
# C:/Users/mssou/pythonfiles/TextFiles/Welcome.txt
# 93
# r
# 4
# False
# True
# None
# True

# %%
# file with, with ensures automatic closing of the file.
import os
fpath= r'C:\Users\mssou\pythonfiles\TextFiles\Welcome.txt'
if os.path.exists(fpath):
     with open(fpath, 'r') as fobj1:
         content = (fobj1.read())
         if(content):
             print(content)
         else:
             print("file is empty")
else:
    print("The file dosent exsits")
# check if file is closed in Python
if fobj1.closed:
    print("File is closed")
else:
    print("File is open")
# Out:
# Welcome to Python.
# 1 Mimo
# 2 Minsi
# 3 Insy
# 4 simon
# 5 cuteness
# 6 mimoness
# 7 sugar
# 8 salt
# File is closed

# %%
#reading files for loop
import os
fpath1= r'C:\Users\mssou\pythonfiles\TextFiles\Welcome.txt'
if os.path.exists(fpath1):
    with open(fpath1, 'r') as fobj2:
         for i in fobj2:
             line = i.strip()
             print(i,end="")

else:
    print("file doesnt exsits")
# Out:
# Welcome to Python.
# 1 Mimo
# 2 Minsi
# 3 Insy
# 4 simon
# 5 cuteness
# 6 mimoness
# 7 sugar
# 8 salt

# %%
# readline

fobj3=open('C:/Users/mssou/pythonfiles/TextFiles/Welcome.txt','r')
print(id(fobj3))
fobj3.seek(0)
print(fobj3.readline())
print(fobj3.readline())
print(fobj3.readlines())
fobj3.close()
# Out:
# 3012533386176
# Welcome to Python.
#
# 1 Mimo
#
# ['2 Minsi\n', '3 Insy\n', '4 simon\n', '5 cuteness\n', '6 mimoness\n', '7 sugar\n', '8 salt']

# %%
# readline contd..
fobj3=open('C:/Users/mssou/pythonfiles/TextFiles/Welcome.txt','r')
print(id(fobj3))
fobj3.seek(0)
filedata=fobj3.readlines()
type(filedata)  # why its not showing list??
print(filedata)
filedata[1]
# Out:
# 3012533371168
# ['Welcome to Python.\n', '1 Mimo\n', '2 Minsi\n', '3 Insy\n', '4 simon\n', '5 cuteness\n', '6 mimoness\n', '7 sugar\n', '8 salt']
# '1 Mimo\n'

# %%
filedata[:]
# Out:
# ['Welcome to Python.\n',
#  '1 Mimo\n',
#  '2 Minsi\n',
#  '3 Insy\n',
#  '4 simon\n',
#  '5 cuteness\n',
#  '6 mimoness\n',
#  '7 sugar\n',
#  '8 salt']

# %%
#reading files for loop
import os
fpath1= r'C:\Users\mssou\pythonfiles\TextFiles\StateData.txt'
if os.path.exists(fpath1):
    with open(fpath1, 'r') as fobj5:
         for i in fobj5:  
             print(i,end="")
else:
    print("file doesnt exsits")
# Out:
# State Code	State Name	District Code	District Name
# 35	ANDAMAN & NICOBAR ISLANDS	638	Nicobars
# 35	ANDAMAN & NICOBAR ISLANDS	639	North and Middle Andaman
# 35	ANDAMAN & NICOBAR ISLANDS	640	South Andaman
# 28	ANDHRAPRADESH	553	Anantapur
# 28	Andhra Pradesh	554	Chittoor
# 28	Andhra Pradesh	545	East Godavari
# 28	Andhra Pradesh	548	Guntur
# 28	ANDHRA PRADESH	547	Krishna
# 28	ANDHRA PRADESH	552	Kurnool
# 28	ANDHRA PRADESH	549	Prakasam
# 28	ANDHRA PRADESH	550	Sri Potti Sriramulu Nellore
# 28	ANDHRA PRADESH	542	Srikakulam
# 28	ANDHRA PRADESH	544	Visakhapatnam
# 28	ANDHRA PRADESH	543	Vizianagaram
# 28	ANDHRA PRADESH	546	West Godavari
# 28	ANDHRA PRADESH	551	Y.S.R.
# 12	ARUNACHAL PRADESH	260	Anjaw
# 12	ARUNACHAL PRADESH	253	Changlang
# 12	ARUNACHAL PRADESH	257	Dibang Valley
# 12	ARUNACHAL PRADESH	247	East Kameng
# 12	ARUNACHAL PRADESH	251	East Siang
# 12	ARUNACHAL PRADESH	953	Kra Daadi
# 12	ARUNACHAL PRADESH	256	Kurung Kumey
# 12	ARUNACHAL PRADESH	259	Lohit
# ...
