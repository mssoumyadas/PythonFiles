# %%
# !pip install pandas

# %%
#creating a data set
import pandas as pd

IshaProg={ "ProgName":["IE","BSP","Soonya","Samyama"],"Cost":[3000,6000,6000,0],"Duration":[7,3.5,4,8]}
IshaProgDataset=pd.DataFrame(IshaProg)
IshaProgDataset
# Out:
#   ProgName  Cost  Duration
# 0       IE  3000       7.0
# 1      BSP  6000       3.5
# 2   Soonya  6000       4.0
# 3  Samyama     0       8.0

# %%
indices = IshaProgDataset.index[IshaProgDataset['ProgName'] == 'IE']
#indicesList= IshaProgDataset.index[IshaProgDataset['ProgName'] == 'IE'or IshaProgDataset['ProgName'] =='BSP' ].tolist()

indicesList
# Out:
# [0]

# %%
IshaProgDataset.iloc[1,0]
# Out:
# 'BSP'

# %%
IshaProgDataset.iloc[:]
# Out:
#   ProgName  Cost  Duration
# 0       IE  3000       7.0
# 1      BSP  6000       3.5
# 2   Soonya  6000       4.0
# 3  Samyama     0       8.0

# %%
#select programs with cost>0
ProgramWithCost= IshaProgDataset[IshaProgDataset[Cost
# Out:
#     Name  Age      City
# 0  Alice   25  New York
# 3  David   40  New York

# %%
import pandas as pd

# raeding from CSV files
dfIn = pd.read_csv('C:\\Users\\mssou\\pythonfiles\\TextFiles\\industry.csv')
print(dfIn.head(3))
print(dfIn.tail(7))
# Out:
#                        Industry  Funds Location
# 0            Accounting/Finance  10000        A
# 1  Advertising/Public Relations  20000        A
# 2            Aerospace/Aviation  20000        A
#                     Industry  Funds Location
# 36                     Sales  30000        C
# 37          Science/Research  30000        C
# 38             Skilled Labor  30000        C
# 39                Technology  30000        C
# 40        Telecommunications  30000        C
# 41  Transportation/Logistics  30000        C
# 42                     Other  40000        C

# %%
#merge of two csv files
dfLc= pd.read_csv('C:\\Users\\mssou\\pythonfiles\\TextFiles\\Location.csv')
mergeddf= pd.merge(dfIn, dfLc, on='Location')
print(mergeddf)
# Out:
#                          Industry  Funds Location Countries  Customers
# 0              Accounting/Finance  10000        A   America         10
# 1    Advertising/Public Relations  20000        A   America         10
# 2              Aerospace/Aviation  20000        A   America         10
# 3   Arts/Entertainment/Publishing  20000        A   America         10
# 4                      Automotive  10000        A   America         10
# 5                Banking/Mortgage  10000        A   America         10
# 6            Business Development  10000        A   America         10
# 7            Business Opportunity  10000        A   America         10
# 8         Clerical/Administrative  10000        A   America         10
# 9         Construction/Facilities  10000        A   America         10
# 10                 Consumer Goods  10000        A   America         10
# 11               Customer Service  50000        A   America         10
# ...

# %%
#Null values
dfIn2 = pd.read_csv('C:\\Users\\mssou\\pythonfiles\\TextFiles\\industry.csv')
print(dfIn2.isnull())
# Out:
#     Industry  Funds  Location
# 0      False  False     False
# 1      False   True     False
# 2      False   True     False
# 3      False  False     False
# 4      False  False     False
# 5      False  False     False
# 6      False  False     False
# 7      False  False     False
# 8      False  False     False
# 9      False  False     False
# 10     False  False     False
# 11     False  False     False
# 12     False  False      True
# 13     False  False     False
# 14     False  False     False
# 15     False  False     False
# 16     False  False     False
# 17     False  False     False
# 18     False  False     False
# 19     False  False     False
# 20     False  False     False
# 21     False   True     False
# 22     False  False     False
# 23     False  False     False
# 24     False  False     False
# 25     False  False     False
# 26     False  False     False
# 27     False  False     False
# 28     False  False     False
# 29     False  False     False
# ...
