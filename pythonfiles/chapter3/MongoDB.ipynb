# %%
pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/959.2 kB ? eta -:--:--
#    -------------------------------- ------- 786.4/959.2 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 959.2/959.2 kB 4.1 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
# ...
