# %%
# regular print statement with format
course="python"
fee=1000
desig=" data science professional."
time= 10.30
print(f"I have joined {course} for a fee of {fee}, to become a {desig}")
#without print
"I have joined {}".format("python")
"course ={},fee={}, time={}".format(course,fee,time)
"I have joined {} the course fee is {} time is {}".format("python", "10K", "10.30")
# question. Why only one line prints out of two without print statements.
#if I write numbers in the braces it wont work.
# Out:
# I have joined python for a fee of 1000, to become a  data science professional.
# 'course =python,fee=1000, time=10.3'

# %%
# new line 
print("welcome\nto\npython")
v="welcome\nto\npython"
print(v)
#type casting
#question what is sigifinace of modulo near variable v?
print("%s" %(v))
print("{}".format(v))
#none casting
print("%r"%(v))
# Out:
# welcome
# to
# python
# welcome
# to
# python
# welcome
# to
# python
# welcome
# to
# python
# 'welcome\nto\npython'

# %%
#print statement with string casting
print("course=%s,fee=%s, designation=%s time=%s" %(course,fee,desig,time))
# Out:
# course=python,fee=1000, designation= data science professional. time=10.3

# %%
#print statement with int, float and string casting
print("course=%s,fee=%i, designation=%s, time=%f" %(course,fee,desig,time))
# Out:
# course=python,fee=1000, designation= data science professional., time=10.300000
