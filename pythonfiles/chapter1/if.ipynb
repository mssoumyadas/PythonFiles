# %%
# if and else if
a= float (input ("enter a number A ="))
b = float (input ("enter a number B="))

if (a > b):
    print(f"{a} is greater than {b}")
elif (a < b):
    print(f"{b} is greater than {a}")
else:
    print(f"{a} is equal to {b}")
# Out:
# enter a number A = 10
# enter a number B= 20
# 20.0 is greater than 10.0

# %%
#ladder if
# sample grading system
mark= float (input("input total Marks"))
maxMark=100
if (mark>=80 and mark<= maxMark):
 print(f"Total Marks :{mark} \n congratulations!! You secured grade A")
elif (mark>=60 and mark< 80):
    print(f"Total Marks :{mark} \n congratulations!! you secured grade B")
elif (mark>40 and mark< 60):
     print(f"Total Marks :{mark} \n congratulations!! you secured grade C")
else:
    print(f"Good luck next time. Total marks:{mark}")
# Out:
# input total Marks 45
# Total Marks :45.0
#  congratulations!! you secured grade C

# %%
# nested if
age = int (input ("enter the driver's age"))
license=  input ("Do you have vallid license? Yes/No:").lower()
if ( age>25 and license =="yes"):
    print("You can drive")
if(age>25 and license=="no"):
    print("get a vallid driver license")
if(age > 25 and (license!="no" and license!="yes")):
    print("invalid input for license")
if(age<25):
    print("user is minor")
# Out:
# enter the driver's age 56
# Do you have vallid license? Yes/No: no
# get a vallid driver license

# %%
#pass
value = int (input ("enter the integer value"))
if value < 0:
  print("Negative value")
elif value == 0:
  pass # Zero case - no action needed
else:
  print("Positive value")
# Out:
# enter the integer value 0
