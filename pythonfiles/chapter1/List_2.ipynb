# %%
#list
fruitlist = ["apple", "banana", "orange", "guava"]
print(fruitlist)
print(len(fruitlist));
list1 = ["abc", 34, True, 40, "male"]
print(type(list1))
print(type(fruitlist))
# Out:
# ['apple', 'banana', 'orange', 'guava']
# 4
# <class 'list'>
# <class 'list'>

# %%
#using list constructor
fruitlist = list(("apple", "banana", "orange", "guava"))
print(fruitlist)
# Out:
# ['apple', 'banana', 'orange', 'guava']
