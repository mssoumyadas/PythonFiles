# %%
a="welcome to this world"
a.

# %%
b="           Hello, Dear World!   "

# %%
print(a.upper())
# Out:
# WELCOME TO THIS WORLD

# %%
print(a.lower())
# Out:
# welcome to this world

# %%
print(a.strip())
# Out:
# welcome to this world

# %%
print(b.strip())
# Out:
# Hello, Dear World!

# %%
print(b)
# Out:
#            Hello, Dear World!
