# %%
a="welcome"

# %%
print(a)
# Out:
# welcome

# %%
print(a[-1],a[-2],a[-3])
# Out:
# e m o

# %%
print(a[0],a[1],a[2])
# Out:
# w e l

# %%
b="hello world"

# %%
print(b[2:5])
# Out:
# llo

# %%
print(b[1:5])
# Out:
# ello

# %%
print(b[0:5])
# Out:
# hello
