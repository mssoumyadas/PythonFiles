# %%
i=1
j=5
while j>=i:
    while i<=j:
        print(i,end="")
        i=i+1
    print("")
    i=1
    j=j-1
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
i=1
j=1
while j<=5:
    while i<=j:
        print(i,end="")
        i=i+1
    print("")
    i=1
    j=j+1

# %%
i = 5
while i >= 1:
    j = 1
    while j <= i:
        print(j, end="")
        j += 1
    print()  # Moves to the next line
    i -= 1
