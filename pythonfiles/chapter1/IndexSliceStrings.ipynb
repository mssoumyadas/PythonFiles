# %%
v1="welcome"
v1[:]
# Out:
# 'welcome'

# %%
print(v1[:])
print (v1[0::1])
print (v1[::])
print (v1[::1])
# Out:
# welcome
# welcome
# welcome
# welcome

# %%
print (v1[::1])
# Out:
# welcome

# %%
print(v1[::-1]) #palindrome
# Out:
# emoclew

# %%
print(v1[3::1]) #I want come
# Out:
# come

# %%
print(v1[-7:-4:1]) #i want wel
#print(-1
# Out:
# wel

# %%
print(v1[-3:-6:-1])
print(v1[4:1:-1])
# Out:
# ocl
# ocl
