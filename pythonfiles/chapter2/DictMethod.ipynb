# %%
Dogs= {'a': 'Akita', 'b': 'beagle', 'c': 'Cocker Spaniel', 'd': 'daschund', 'e': 'English Bulldog', 'h': 'Huskey'}
Num1={1:10,2:20,3:30,4:40,5:50}

# %%
pprint
# Out:
# Pretty printing has been turned ON

# %%
dir(Num1)
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
#clear, copy,pop (removes item with the key), popitem (removes the last item)  skipped
Num1={1:10,2:20,3:30,4:40,5:50}
NumList=[1,2,3,4,5]
# fromkeys
Num2= dict.fromkeys(NumList,"default")
print(Num2)
# Out:
# {1: 'default', 2: 'default', 3: 'default', 4: 'default', 5: 'default'}

# %%
#get
#Num1.get(3)
Num1.get(10) # no error on get but index would throw error.
#items
Num1.items() # keeps dictonary key values in a tuple) class dict_items
print(Num1)

car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = car.items()
print(x)

#dict item class can be read only with for loop.
d = {'A': 'Python', 'B': 'Java', 'C': 'C++'}

# using items() to iterate over dictionary
for key, value in d.items():
    print(f"Key: {key}, Value: {value}")
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50}
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])
# Key: A, Value: Python
# Key: B, Value: Java
# Key: C, Value: C++

# %%
#values
d.values()
for i in d.values():
 print(i)
# Out:
# Python
# Java
# C++

# %%
for i in d.keys(): # to retrive keys of dict, but mostly not needed as simple i would refer to key only.
 print(i)
# Out:
# A
# B
# C

# %%
for i in d:
 print(i)
# Out:
# A
# B
# C

# %%
#setdefault
Num1={1:10,2:20,3:30,4:40,5:50}
Num1.setdefault(6,600)
Num1
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 600}

# %%
Num1.setdefault(3,600)
Num1
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 600}

# %%
#update
Num1={1:10,2:20,3:30,4:40,5:50}
Num2={1:11,2:22,3:30,6:60,7:70}
print(Num1)
print(Num2)
Num1.update(Num2)
print(Num1)
print(Num2)
Num1.update({8:88,9:99})
print(Num1)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50}
# {1: 11, 2: 22, 3: 30, 6: 60, 7: 70}
# {1: 11, 2: 22, 3: 30, 4: 40, 5: 50, 6: 60, 7: 70}
# {1: 11, 2: 22, 3: 30, 6: 60, 7: 70}
# {1: 11, 2: 22, 3: 30, 4: 40, 5: 50, 6: 60, 7: 70, 8: 88, 9: 99}
