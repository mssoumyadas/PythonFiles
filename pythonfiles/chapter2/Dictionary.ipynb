# %%
#For dic the key can not be iterarable

week={1:"Mon",2:"Tue",3:"wed"}
Num1={1:10,2:20,3:30}
Dogs={'a':"Akita",'b':"beagle",'c':"Cocker Spaniel",'d':"dalmatian", 'e':"English Bulldog"}
StudentList={101:["Sal","python",1500],102: ["Sam","java",2500],103: ["San","R",1500]} #dict ,containg list as value
StudentDict= {
    101: {'name':"Sal",'course':"python",'fee': 1500},
    102: {'name':"Sam",'course':"java",'fee': 2500},
    103: {'name':"San",'course':"R",'fee':1500}
} #dict containg dict as value

print(week)
print(Num1)
print(Dogs)
print(StudentList)
print(StudentDict)

#formkeys with multidimensiona list
# you can not read items with index only for loop
# Out:
# {1: 'Mon', 2: 'Tue', 3: 'wed'}
# {1: 10, 2: 20, 3: 30}
# {'a': 'Akita', 'b': 'beagle', 'c': 'Cocker Spaniel', 'd': 'dalmatian', 'e': 'English Bulldog'}
# {101: ['Sal', 'python', 1500], 102: ['Sam', 'java', 2500], 103: ['San', 'R', 1500]}
# {101: {'name': 'Sal', 'course': 'python', 'fee': 1500}, 102: {'name': 'Sam', 'course': 'java', 'fee': 2500}, 103: {'name': 'San', 'course': 'R', 'fee': 1500}}

# %%
#acsessing Dict element
print(week[1])
print (Dogs['c'])
print(StudentDict[101]['name'])
print(StudentDict[101]['name'][0])
# Out:
# Mon
# Cocker Spaniel
# Sal
# S

# %%
#with variable
a='apple'
b='banana'
c='cherry'
DF={1:a,2:b,3:c}
print(DF)
# Out:
# {1: 'apple', 2: 'banana', 3: 'cherry'}

# %%
D = {}
type(D) # not working
D1= dict()
type (D1)
# Out:
# dict

# %%
# updating key present would be updated, if not then added.
Dogs={'a':"Akita",'b':"beagle",'c':"Cocker Spaniel",'d':"dalmatian", 'e':"English Bulldog"}
Dogs['d']="daschund"
Dogs['h']="Huskey"
print(Dogs)
# Out:
# {'a': 'Akita', 'b': 'beagle', 'c': 'Cocker Spaniel', 'd': 'daschund', 'e': 'English Bulldog', 'h': 'Huskey'}

# %%
# For loop prints only keys 
for i in Dogs:
    print(i)
# Out:
# a
# b
# c
# d
# e
# h

# %%
#For loop value
for i in Dogs:
    print(Dogs[i])
# Out:
# Akita
# beagle
# Cocker Spaniel
# daschund
# English Bulldog
# Huskey
