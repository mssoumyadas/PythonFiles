# %%
#list
L1=[1,2,3,4]
print(L1)
type(L1)
# List can be of any type and even mixed type like some element can be string and some can be 
#empty list
# Out:
# [1, 2, 3, 4]
# list

# %%
L2=[]
L2 # empty list
# Out:
# []

# %%
L3= list() # empty list with constructor
L3
# Out:
# []

# %%
L4=list("CatBaby") #using constructor to create string class list
print(L4)
L6= list([10,20,30]) #using constructor to create int class list
print(L6)
L7= list(["cat", 1, "dog", 1, "bird",2]) #using constructor to create mixed class list
print(L7)
# Out:
# ['C', 'a', 't', 'B', 'a', 'b', 'y']
# [10, 20, 30]
# ['cat', 1, 'dog', 1, 'bird', 2]

# %%
# creating list with Range , range works by incrementing by 5 in below exmaple till 30
L5= list(range(0,30,5))
print(L5)
for i in L5:
    print(i)
# Out:
# [0, 5, 10, 15, 20, 25]
# 0
# 5
# 10
# 15
# 20
# 25
