# %%
#sets Methods skipped copy, clear, discard, intersection,intersection_update, issuperset,issubset,pop (removes the first element), 
#remove (removes the given element). Check diff btn discard, pop and remove
#symetricdifference,ymetricdifference_update
s1={10,20,30}
s1.add(40)
print(s1)
# Out:
# {40, 10, 20, 30}

# %%
s1={10,20,30}
s2={10,40,50}
s1.difference(s2)
# Out:
# {20, 30}

# %%
s1.difference_update(s2)
print(s1) # the difference is updated in the set value
# Out:
# {20, 30}

# %%
s1.isdisjoint(s2)
# Out:
# True

# %%
s1.union(s2)
# Out:
# {10, 20, 30, 40, 50}

# %%
sorted(s1.union(s2),reverse=True)
# Out:
# [50, 40, 30, 20, 10]

# %%
s1={10,20,30}
s2={10,40,50,60}
s1.update(s2)
print(s1)
# Out:
# {50, 20, 40, 10, 60, 30}
